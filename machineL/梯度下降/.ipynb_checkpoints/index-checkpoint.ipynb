# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x : (x -3.5)**2 - 4.5*x +10
# 导数
d =lambda x : 2*(x-3.5) - 4.5

step =0.1

x =np.random.randint(0,12,size=1)[0]

last_x =x+0.02

precision =1e-4
print("++++++++++++++",x)
x_= [x]

while True:
    if np.abs(x -last_x) <precision:
        break
        
    last_x =x 
    x -= step*d(x) # 更新最小值
    x_.append(x)
    print("---------",x)
    
plt.rcParams['font.family'] = 'kaiti SC'
plt.figure(figsize=(9,6))
x= np.linspace(5.75-5,5.75+5, 100)
y=f(x)
plt.plot(x,y,color="green")
plt.title("梯度下降",size=24,pad=15)
x_ =np.array(x_)
y_ =f(x_)
plt.scatter(x_,y_,color='red')
plt.savefig('./images/5-梯度下降.jpg',dpi=200)
# Out:
# findfont: Font family ['kaiti SC'] not found. Falling back to DejaVu Sans.
# ++++++++++++++ 4
# --------- 4.35
# --------- 4.63
# --------- 4.854
# --------- 5.0332
# --------- 5.17656
# --------- 5.291248
# --------- 5.3829984
# --------- 5.45639872
# --------- 5.515118976
# --------- 5.5620951808
# --------- 5.59967614464
# --------- 5.629740915712
# --------- 5.653792732569601
# --------- 5.6730341860556805
# --------- 5.688427348844544
# --------- 5.700741879075635
# --------- 5.710593503260508
# --------- 5.718474802608407
# --------- 5.7247798420867255
# --------- 5.72982387366938
# --------- 5.733859098935504
# --------- 5.737087279148403
# --------- 5.739669823318723
# --------- 5.7417358586549785
# --------- 5.743388686923983
# --------- 5.744710949539186
# --------- 5.745768759631349
# --------- 5.7466150077050795
# --------- 5.747292006164064
# --------- 5.747833604931251
# --------- 5.748266883945001
# --------- 5.7486135071560005
# --------- 5.7488908057248
# ...
